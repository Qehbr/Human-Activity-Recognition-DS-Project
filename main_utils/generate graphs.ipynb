# %%
from matplotlib import pyplot as plt

# %%
# lstm auto encoder
lstm_ae_training_loss_type1 = [0.1262, 0.1080, 0.0865, 0.0566, 0.0180, 0.0078, 0.0077, 0.0077, 0.0077, 0.0077, 0.0077,
                               0.0077, 0.0077, 0.0077, 0.0077]
lstm_ae_validation_loss_type1 = [0.1179, 0.0986, 0.0739, 0.0371, 0.0081, 0.0078, 0.0078, 0.0078, 0.0078, 0.0078, 0.0078,
                                 0.0078, 0.0077, 0.0077, 0.0077]

lstm_ae_training_loss_type2 = [0.2025, 0.0725, 0.0160, 0.0155, 0.0149, 0.0143, 0.0137, 0.0132, 0.0126, 0.0118, 0.0109,
                               0.0100, 0.0095, 0.0092, 0.0089]
lstm_ae_validation_loss_type2 = [0.1554, 0.0162, 0.0157, 0.0151, 0.0145, 0.0138, 0.0133, 0.0128, 0.0121, 0.0112, 0.0103,
                                 0.0096, 0.0092, 0.0089, 0.0087]

epochs = range(1, len(lstm_ae_training_loss_type1) + 1)
plt.figure(figsize=(12, 6))

# Type 1
plt.subplot(1, 2, 1)
plt.plot(epochs, lstm_ae_training_loss_type1, label='Training loss')
plt.plot(epochs, lstm_ae_validation_loss_type1, label='Validation loss')
plt.title('Type 1 LSTM Autoencoder')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Type 2
plt.subplot(1, 2, 2)
plt.plot(epochs, lstm_ae_training_loss_type2, label='Training loss')
plt.plot(epochs, lstm_ae_validation_loss_type2, label='Validation loss')
plt.title('Type 2 LSTM Autoencoder')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# lstm features extractor
lstm_fe_training_loss_type1 = [
    2.6606, 2.4947, 2.4330, 2.4021, 2.3845, 2.3708, 2.3609, 2.3522, 2.3454, 2.3397,
    2.3334, 2.3277, 2.3228, 2.3183, 2.3141, 2.3108, 2.3074, 2.3036, 2.3006, 2.2977,
    2.2945, 2.2915, 2.2886, 2.2864, 2.2841, 2.2821, 2.2796, 2.2779, 2.2761, 2.2746,
    2.2724, 2.2715, 2.2701, 2.2684, 2.2665, 2.2656, 2.2642, 2.2630, 2.2615, 2.2604,
    2.2594, 2.2581, 2.2568, 2.2560, 2.2548, 2.2540, 2.2526, 2.2518, 2.2510, 2.2501,
    2.2488, 2.2477, 2.2477, 2.2465, 2.2455, 2.2452, 2.2444, 2.2431, 2.2426, 2.2417,
    2.2413, 2.2405, 2.2397, 2.2391, 2.2387, 2.2378, 2.2373, 2.2367, 2.2360, 2.2353,
    2.2347, 2.2342, 2.2337, 2.2329, 2.2325, 2.2324, 2.2318, 2.2310, 2.2298, 2.2294,
    2.2287, 2.2283, 2.2279, 2.2272, 2.2273, 2.2265, 2.2261, 2.2258, 2.2254, 2.2252,
    2.2244, 2.2242, 2.2236, 2.2238, 2.2231, 2.2227, 2.2226, 2.2220, 2.2221, 2.2213
]

lstm_fe_validation_loss_type1 = [
    2.5384, 2.4545, 2.4131, 2.3947, 2.3792, 2.3707, 2.3614, 2.3554, 2.3490, 2.3446,
    50.37, 50.55, 50.96, 51.41, 51.69, 52.15, 52.48, 52.77, 53.03, 53.13,
    53.39, 53.60, 53.92, 53.90, 54.40, 54.43, 54.67, 54.72, 54.95, 54.78,
    55.20, 55.56, 55.67, 55.51, 55.67, 55.86, 56.17, 56.20, 56.21, 56.41,
    56.46, 56.81, 56.99, 57.14, 57.49, 57.36, 57.47, 57.67, 57.61, 58.05,
    58.21, 58.29, 58.46, 58.82, 58.91, 58.96, 59.01, 59.25, 59.18, 59.40,
    59.64, 59.56, 59.77, 59.89, 60.00, 59.88, 60.14, 60.22, 60.31, 60.29,
    60.46, 60.61, 60.55, 60.72, 60.70, 60.90, 60.76, 60.93, 60.98, 61.29,
    61.19, 61.16, 61.35, 61.35, 61.50, 61.58, 61.57, 61.74, 61.65, 61.89
]

validation_acc_type2 = [
    22.61, 29.40, 31.75, 33.20, 36.83, 40.10, 42.05, 43.33, 44.26, 44.40,
    45.25, 44.76, 45.61, 46.78, 46.85, 47.10, 48.20, 48.52, 48.99, 48.92,
    49.38, 49.24, 49.45, 49.63, 50.16, 50.37, 51.08, 50.91, 50.48, 51.62,
    51.37, 51.87, 52.22, 52.08, 51.94, 52.26, 52.04, 52.33, 52.79, 52.51,
    52.76, 52.58, 52.79, 53.00, 52.86, 52.68, 53.18, 53.15, 53.08, 53.36,
    53.11, 53.50, 53.47, 53.15, 53.32, 53.71, 54.03, 53.89, 54.14, 54.35,
    54.50, 54.46, 54.78, 54.89, 55.03, 54.67, 55.24, 55.10, 55.39, 54.96,
    55.39, 55.49, 55.46, 55.39, 55.46, 55.60, 56.03, 55.95, 56.20, 56.31,
    56.38, 56.38, 56.31, 56.24, 56.56, 56.52, 56.49, 56.81, 56.67, 56.99,
    56.74, 56.38, 57.27, 56.88, 57.02, 57.20, 57.59, 57.45, 56.88, 57.45
]

# Data
epochs_type1 = range(1, len(lstm_fe_training_loss_type1) + 1)
epochs_type2 = range(1, len(training_loss_type2) + 1)

# Type 1 LSTM Feature Extractor
plt.figure(figsize=(12, 10))

# Loss
plt.subplot(2, 2, 1)
plt.plot(epochs_type1, lstm_fe_training_loss_type1, label='Training loss')
plt.plot(epochs_type1, lstm_fe_validation_loss_type1, label='Validation loss')
plt.title('Type 1 LSTM Feature Extractor Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy
plt.subplot(2, 2, 2)
plt.plot(epochs_type1, lstm_fe_training_acc_type1, label='Training accuracy')
plt.plot(epochs_type1, lstm_fe_validation_acc_type1, label='Validation accuracy')
plt.title('Type 1 LSTM Feature Extractor Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Type 2 LSTM Feature Extractor
plt.subplot(2, 2, 3)
plt.plot(epochs_type2, training_loss_type2, label='Training loss')
plt.plot(epochs_type2, validation_loss_type2, label='Validation loss')
plt.title('Type 2 LSTM Feature Extractor Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy
plt.subplot(2, 2, 4)
plt.plot(epochs_type2, training_acc_type2, label='Training accuracy')
plt.plot(epochs_type2, validation_acc_type2, label='Validation accuracy')
plt.title('Type 2 LSTM Feature Extractor Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# 3D CNN before fine tuning
d3cnn_training_loss_type1 = [2.8453, 1.8566, 1.7717, 1.7103, 1.6664, 1.6166, 1.5777, 1.501, 1.3784, 1.1858, 0.9694,
                           0.8294, 0.6201, 0.4884, 0.3826, 0.2978, 0.2561, 0.2061, 0.1853, 0.191, 0.1252, 0.1169,
                           0.1154, 0.1108, 0.1103, 0.1097, 0.1091, 0.1091, 0.1091, 0.1089]

d3cnn_validation_loss_type1 = [1.8948, 1.8002, 1.7457, 1.6798, 1.6656, 1.617, 1.5696, 1.5016, 1.3899, 1.2641, 1.1417,
                             1.0917, 0.9814, 0.9975, 0.9417, 0.9124, 0.9044, 0.94, 0.9759, 1.0204, 0.9953, 0.9997,
                             1.0129, 1.0071, 1.0081, 1.0079, 1.0088, 1.0091, 1.0091, 1.009]

d3cnn_training_acc_type1 = [15.38, 22.85, 26.7, 29.22, 30.67, 33.27, 35.06, 38.74, 45.27, 54.61, 65.04, 71.2, 78.57,
                          83.86, 87.93, 90.48, 92.05, 93.34, 93.87, 93.97, 96.22, 96.28, 96.52, 96.76, 96.74, 96.72,
                          96.76, 96.76, 96.76, 96.76]

d3cnn_validation_acc_type1 = [19.13, 22.82, 27.27, 28.9, 30.96, 31.92, 33.63, 37.58, 44.9, 49.45, 57.27, 61.39, 67.65,
                            66.76, 72.98, 76.11, 77.71, 78.71, 78.67, 77.21, 79.95, 80.48, 80.23, 80.13, 80.09, 80.02,
                            80.02, 80.02, 80.02, 80.02]

d3cnn_training_loss_type2 = [1.2405, 0.509, 0.2538, 0.1417, 0.0909, 0.0923, 0.0623, 0.0546, 0.0128, 0.0073, 0.0061,
                           0.0051, 0.005, 0.0048, 0.0047, 0.0047, 0.0046, 0.0046, 0.0046, 0.0046]

d3cnn_validation_loss_type2 = [0.7674, 0.5778, 0.4036, 0.4317, 0.3591, 0.419, 0.4524, 0.5228, 0.3894, 0.3956, 0.4015,
                             0.4031, 0.4041, 0.4054, 0.4054, 0.4054, 0.4055, 0.4055, 0.4056, 0.4056]

d3cnn_training_acc_type2 = [56.91, 81.39, 91.34, 95.24, 96.95, 96.92, 98.14, 98.20, 99.69, 99.87, 99.89, 99.89, 99.91,
                          99.91, 99.92, 99.91, 99.92, 99.92, 99.92, 99.92]

d3cnn_validation_acc_type2 = [71.75, 80.51, 88.37, 89.25, 90.95, 90.66, 90.33, 90.07, 93.89, 93.98, 94.09, 94.02, 94.03,
                            94.00, 94.00, 94.00, 94.00, 94.00, 94.00, 94.00]

# Data
epochs_type1 = range(1, len(d3cnn_training_loss_type1) + 1)
epochs_type2 = range(1, len(d3cnn_training_loss_type2) + 1)

# Type 1 CNN
plt.figure(figsize=(12, 10))

# Loss
plt.subplot(2, 2, 1)
plt.plot(epochs_type1, d3cnn_training_loss_type1, label='Training loss')
plt.plot(epochs_type1, d3cnn_validation_loss_type1, label='Validation loss')
plt.title('Type 1 3D CNN Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy
plt.subplot(2, 2, 2)
plt.plot(epochs_type1, d3cnn_training_acc_type1, label='Training accuracy')
plt.plot(epochs_type1, d3cnn_validation_acc_type1, label='Validation accuracy')
plt.title('Type 1 3D CNN Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Type 2 CNN
# Loss
plt.subplot(2, 2, 3)
plt.plot(epochs_type2, d3cnn_training_loss_type2, label='Training loss')
plt.plot(epochs_type2, d3cnn_validation_loss_type2, label='Validation loss')
plt.title('Type 2 3D CNN Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy
plt.subplot(2, 2, 4)
plt.plot(epochs_type2, d3cnn_training_acc_type2, label='Training accuracy')
plt.plot(epochs_type2, d3cnn_validation_acc_type2, label='Validation accuracy')
plt.title('Type 2 3D CNN Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# lstm + cnn 
lstm_cnn_training_loss_type1 = [2.2161, 1.8019, 1.6337, 1.5354, 1.4529, 1.2810, 1.1334, 0.9791, 0.8272, 0.6598, 0.5497,
                                0.5273, 0.3942, 0.2475, 0.2156, 0.2008, 0.1899, 0.1755, 0.1721, 0.1703, 0.1685, 0.1682,
                                0.1682, 0.1679, 0.1679, 0.168, 0.1679, 0.1679, 0.1679, 0.1677]
lstm_cnn_validation_loss_type1 = [1.9149, 1.7098, 1.6207, 1.6332, 1.4482, 1.3676, 1.2391, 1.1709, 1.0866, 0.9642,
                                  1.1998, 0.9679, 1.0161, 0.9176, 0.9462, 0.9798, 1.0048, 1.0039, 1.0097, 1.011, 1.0127,
                                  1.014, 1.0149, 1.015, 1.0151, 1.0152, 1.0152, 1.0152, 1.0152, 1.0152]
lstm_cnn_training_acc_type1 = [16.98, 24.83, 32.18, 37.52, 41.45, 50.44, 57.02, 63.07, 69.4, 75.68, 80.1, 81.03, 85.53,
                               91.5, 92.49, 93.01, 93.01, 93.8, 93.97, 94.04, 94.11, 94.06, 94.09, 94.08, 94.08, 94.08,
                               94.08, 94.08, 94.08, 94.08]
lstm_cnn_validation_acc_type1 = [19.55, 26.48, 33.49, 32.99, 39.64, 44.97, 52.65, 56.74, 61.82, 70.81, 67.4, 72.56,
                                 75.01, 77.64, 79.24, 79.42, 79.35, 79.81, 80.06, 80.23, 80.2, 80.23, 80.16, 80.16,
                                 80.16, 80.16, 80.16, 80.16, 80.16, 80.16]

lstm_cnn_training_loss_type2 = [1.5526, 0.9935, 0.6953, 0.4761, 0.3189, 0.237, 0.1566, 0.1249, 0.116, 0.1209, 0.0692,
                                0.0236, 0.0163, 0.0135, 0.0108, 0.0104, 0.01, 0.01, 0.0099, 0.0099]
lstm_cnn_validation_loss_type2 = [1.2137, 0.839, 0.6527, 0.5872, 0.5523, 0.5602, 0.4795, 0.4919, 0.4495, 0.512, 0.5291,
                                  0.4482, 0.462, 0.4634, 0.4677, 0.4696, 0.4696, 0.4695, 0.4695, 0.4696]
lstm_cnn_training_acc_type2 = [41.11, 61.19, 73.06, 81.82, 87.8, 91.29, 94.3, 95.45, 95.84, 95.84, 97.59, 99.29, 99.52,
                               99.64, 99.74, 99.75, 99.78, 99.77, 99.79, 99.79]
lstm_cnn_validation_acc_type2 = [50.98, 68.15, 73.79, 78.92, 81.32, 84.58, 88.92, 88.35, 90.34, 89.6, 90.59, 92.82,
                                 92.94, 93.37, 93.4, 93.38, 93.41, 93.42, 93.42, 93.42]

import matplotlib.pyplot as plt

# Data
epochs_type1 = range(1, len(lstm_cnn_training_loss_type1) + 1)
epochs_type2 = range(1, len(lstm_cnn_training_loss_type2) + 1)

# Type 1 LSTM + CNN
plt.figure(figsize=(12, 10))

# Loss
plt.subplot(2, 2, 1)
plt.plot(epochs_type1, lstm_cnn_training_loss_type1, label='Training loss')
plt.plot(epochs_type1, lstm_cnn_validation_loss_type1, label='Validation loss')
plt.title('Type 1 LSTM + CNN Feature Extractor Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy
plt.subplot(2, 2, 2)
plt.plot(epochs_type1, lstm_cnn_training_acc_type1, label='Training accuracy')
plt.plot(epochs_type1, lstm_cnn_validation_acc_type1, label='Validation accuracy')
plt.title('Type 1 LSTM + CNN Feature Extractor Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Type 2 LSTM + CNN
plt.subplot(2, 2, 3)
plt.plot(epochs_type2, lstm_cnn_training_loss_type2, label='Training loss')
plt.plot(epochs_type2, lstm_cnn_validation_loss_type2, label='Validation loss')
plt.title('Type 2 LSTM + CNN Feature Extractor Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy
plt.subplot(2, 2, 4)
plt.plot(epochs_type2, lstm_cnn_training_acc_type2, label='Training accuracy')
plt.plot(epochs_type2, lstm_cnn_validation_acc_type2, label='Validation accuracy')
plt.title('Type 2 LSTM + CNN Feature Extractor Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# 3d cnn after norm + fine tuning
d3cnn_training_loss_type1 = [2.1674, 1.7240, 1.6076, 1.5234, 1.4191, 1.2847, 1.1175, 0.9346, 0.7423, 0.5852, 0.4945,
                             0.4019, 0.3209, 0.2759, 0.2679, 0.2295, 0.1813, 0.2029, 0.2050, 0.1286, 0.1145, 0.1094,
                             0.1068, 0.1047, 0.1026, 0.0979, 0.0970, 0.0967, 0.0960, 0.0961]
d3cnn_validation_loss_type1 = [1.8045, 1.6188, 1.5606, 1.4902, 1.3950, 1.2644, 1.1408, 1.0295, 0.8426, 0.7631, 0.6947,
                               0.6051, 0.5144, 0.5100, 0.5058, 0.4049, 0.4397, 0.4522, 0.4682, 0.3631, 0.3631, 0.3622,
                               0.3656, 0.3646, 0.3662, 0.3648, 0.3657, 0.3663, 0.3659, 0.3658]
d3cnn_training_acc_type1 = [18.23, 27.79, 32.39, 36.55, 41.84, 48.96, 56.78, 64.26, 72.75, 79.34, 82.59, 86.08, 88.96,
                            90.58, 90.88, 92.06, 93.72, 93.03, 92.93, 95.97, 96.25, 96.5, 96.56, 96.56, 96.71, 96.79,
                            96.8, 96.84, 96.85, 96.88]
d3cnn_validation_acc_type1 = [23.27, 31.89, 32.35, 38.22, 42.34, 49.43, 56.6, 61.67, 68.84, 73.43, 76.48, 81.11, 84.14,
                              85.63, 85.19, 89.48, 87.8, 87.71, 87.12, 91.27, 91.63, 91.63, 91.91, 92.07, 92.11, 92.25,
                              92.18, 92.16, 92.32, 92.37]

d3cnn_training_loss_type2 = [1.3487, 0.7015, 0.4254, 0.2859, 0.1939, 0.1397, 0.1219, 0.09, 0.0269, 0.0205, 0.018,
                             0.0162, 0.0151, 0.0137, 0.0125, 0.0117, 0.0087, 0.0084, 0.0082, 0.008]
d3cnn_validation_loss_type2 = [0.9424, 0.541, 0.3755, 0.3001, 0.2398, 0.1918, 0.3179, 0.1941, 0.1111, 0.1086, 0.1055,
                               0.1046, 0.1059, 0.1043, 0.1089, 0.1062, 0.1041, 0.1042, 0.1041, 0.1041]
d3cnn_training_acc_type2 = [48.38, 73.4, 84.15, 89.55, 93.17, 95.25, 95.78, 96.96, 99.33, 99.51, 99.56, 99.63, 99.62,
                            99.68, 99.68, 99.74, 99.84, 99.84, 99.84, 99.85]
d3cnn_validation_acc_type2 = [63.91, 80.12, 86.48, 89.07, 92.37, 93.88, 91.01, 94.95, 97.3, 97.5, 97.79, 97.76, 97.82,
                              97.97, 97.77, 98.03, 98.06, 98.11, 98.12, 98.1]

# Data
epochs_type1 = range(1, len(d3cnn_training_loss_type1) + 1)
epochs_type2 = range(1, len(d3cnn_training_loss_type2) + 1)

# Type 1 3D CNN
plt.figure(figsize=(12, 10))

# Loss
plt.subplot(2, 2, 1)
plt.plot(epochs_type1, d3cnn_training_loss_type1, label='Training loss')
plt.plot(epochs_type1, d3cnn_validation_loss_type1, label='Validation loss')
plt.title('Type 1 3D CNN Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy
plt.subplot(2, 2, 2)
plt.plot(epochs_type1, d3cnn_training_acc_type1, label='Training accuracy')
plt.plot(epochs_type1, d3cnn_validation_acc_type1, label='Validation accuracy')
plt.title('Type 1 3D CNN Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Type 2 3D CNN
plt.subplot(2, 2, 3)
plt.plot(epochs_type2, d3cnn_training_loss_type2, label='Training loss')
plt.plot(epochs_type2, d3cnn_validation_loss_type2, label='Validation loss')
plt.title('Type 2 3D CNN Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy
plt.subplot(2, 2, 4)
plt.plot(epochs_type2, d3cnn_training_acc_type2, label='Training accuracy')
plt.plot(epochs_type2, d3cnn_validation_acc_type2, label='Validation accuracy')
plt.title('Type 2 3D CNN Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# 1d cnn
cnn_training_loss_type1 = [2.1252, 1.5334, 1.2239, 0.8869, 0.5833, 0.3572, 0.2417, 0.1942, 0.1584, 0.1128,
                                    0.0931, 0.0854, 0.0795, 0.075, 0.0738, 0.0732, 0.0726, 0.0727, 0.0724, 0.0724,
                                    0.0723, 0.0723, 0.0723, 0.0723, 0.0724, 0.0725, 0.0723, 0.0724, 0.0724, 0.0723]
cnn_validation_loss_type1 = [1.7018, 1.4520, 1.2827, 1.0689, 0.9463, 0.9346, 0.9497, 0.9777, 1.0293, 0.9194,
                                      0.9322, 0.9413, 0.9567, 0.9523, 0.9541, 0.9545, 0.9551, 0.9554, 0.9556, 0.9556,
                                      0.9556, 0.9556, 0.9556, 0.9556, 0.9556, 0.9556, 0.9556, 0.9556, 0.9556, 0.9556]
cnn_training_acc_type1 = [22.80, 37.70, 53.04, 67.80, 79.48, 87.66, 91.47, 93.08, 94.50, 96.20, 96.91, 97.08,
                                   97.40, 97.25, 97.19, 97.26, 97.28, 97.29, 97.29, 97.30, 97.30, 97.30, 97.30, 97.31,
                                   97.31, 97.31, 97.31, 97.31, 97.31, 97.31]
cnn_validation_acc_type1 = [28.23, 42.30, 49.63, 60.50, 67.22, 69.93, 72.98, 74.40, 73.37, 78.67, 79.13, 79.38,
                                     78.99, 79.27, 79.17, 79.17, 79.17, 79.20, 79.31, 79.31, 79.31, 79.31, 79.31, 79.31,
                                     79.31, 79.31, 79.31, 79.31, 79.31, 79.31]
cnn_training_loss_type2 = [1.6033, 0.6654, 0.3912, 0.2544, 0.2017, 0.1688, 0.1585, 0.1054, 0.0432, 0.0280,
                                    0.0242, 0.0219, 0.0185, 0.0178, 0.0174, 0.0170, 0.0170, 0.0169, 0.0168, 0.0168]
cnn_validation_loss_type2 = [0.9323, 0.6520, 0.6255, 0.5644, 0.5154, 0.8059, 0.5730, 0.5723, 0.4496, 0.4569,
                                      0.4571, 0.4602, 0.4589, 0.4603, 0.4608, 0.4610, 0.4610, 0.4612, 0.4612, 0.4612]
cnn_training_acc_type2 = [50.55, 75.39, 85.53, 90.92, 93.21, 94.55, 94.58, 96.27, 98.75, 99.18, 99.28, 99.35,
                                   99.45, 99.45, 99.47, 99.48, 99.50, 99.51, 99.51, 99.50]
cnn_validation_acc_type2 = [64.55, 76.33, 79.62, 82.09, 85.31, 81.32, 86.53, 86.21, 90.36, 90.85, 90.90, 90.94,
                                     91.02, 91.05, 91.06, 91.06, 91.06, 91.03, 91.03, 91.03]


# Data
epochs_type1 = range(1, len(cnn_training_loss_type1) + 1)
epochs_type2 = range(1, len(cnn_training_loss_type2) + 1)

# Type 1 3D CNN
plt.figure(figsize=(12, 10))

# Loss
plt.subplot(2, 2, 1)
plt.plot(epochs_type1, cnn_training_loss_type1, label='Training loss')
plt.plot(epochs_type1, cnn_validation_loss_type1, label='Validation loss')
plt.title('Type 1 1D CNN Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy
plt.subplot(2, 2, 2)
plt.plot(epochs_type1, cnn_training_acc_type1, label='Training accuracy')
plt.plot(epochs_type1, cnn_validation_acc_type1, label='Validation accuracy')
plt.title('Type 1 1D CNN Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Type 2 3D CNN
plt.subplot(2, 2, 3)
plt.plot(epochs_type2, cnn_training_loss_type2, label='Training loss')
plt.plot(epochs_type2, cnn_validation_loss_type2, label='Validation loss')
plt.title('Type 2 1D CNN Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy
plt.subplot(2, 2, 4)
plt.plot(epochs_type2, cnn_training_acc_type2, label='Training accuracy')
plt.plot(epochs_type2, cnn_validation_acc_type2, label='Validation accuracy')
plt.title('Type 2 1D CNN Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
